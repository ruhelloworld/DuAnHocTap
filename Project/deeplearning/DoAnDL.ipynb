# %% [markdown]
# **Import các thư viện cần thiết**

# %%
import os
import numpy as np
from pathlib import Path
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.keras.utils import to_categorical, img_to_array, load_img
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input, Rescaling, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, MaxPool2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, ZeroPadding2D
from tensorflow.keras.models import load_model, Model, Sequential
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom
import matplotlib.pyplot as plt

# %% [markdown]
# **Chuẩn bị dữ liệu**

# %%
BASE_PATH = "/content/drive/MyDrive/Colab Notebooks/Data"
TRAIN_PATH = 'Train'
VALID_PATH = 'Valid'
TEST_PATH = 'Test'
CLASSES = ['Eraser', 'Pen', 'Pencil_Sharpener', 'Ruler', 'Stapler']
IMG_SIZE = (224,224)
train_dataset = image_dataset_from_directory(
 Path.cwd() / BASE_PATH / TRAIN_PATH ,
 image_size=(224, 224),
 batch_size=32,
 label_mode='categorical')
validation_dataset = image_dataset_from_directory(
 Path.cwd() / BASE_PATH / VALID_PATH ,
 image_size=(224, 224),
 batch_size=32,
 label_mode='categorical')
test_dataset = image_dataset_from_directory(
 Path.cwd() / BASE_PATH / TEST_PATH ,
 image_size=(224, 224),
 batch_size=32,
 label_mode='categorical')
# Out:
# Found 1841 files belonging to 5 classes.
# Found 373 files belonging to 5 classes.
# Found 496 files belonging to 5 classes.

# %% [markdown]
# **Mô hình MLP**

# %%
def MLP():
    inputs = Input(shape=(224, 224, 3))
    x = Flatten()(inputs)
    x = Dense(units=256, activation='relu')(x)
    x = Dense(units=128, activation='relu')(x)
    outputs = Dense(units=5, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Tạo model
model = MLP()
print(model.summary())
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  flatten_4 (Flatten)         (None, 150528)            0
#
#  dense_14 (Dense)            (None, 256)               38535424
#
#  dense_15 (Dense)            (None, 128)               32896
#
#  dense_16 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 38568965 (147.13 MB)
# Trainable params: 38568965 (147.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Compile mô hình
model.compile(loss="categorical_crossentropy",
 optimizer="adam",
 metrics=["accuracy"])
callbacks = [ ModelCheckpoint(
 filepath="mlp.keras",
 save_best_only=True,
 monitor="val_loss")
]
# train mô hình
H = model.fit(
 train_dataset,
 epochs=50,
 validation_data=validation_dataset,
 callbacks=callbacks)
# Out:
# Epoch 1/50
# 58/58 [==============================] - 28s 412ms/step - loss: 11404.6592 - accuracy: 0.2596 - val_loss: 2654.6516 - val_accuracy: 0.2413
# Epoch 2/50
# 58/58 [==============================] - 27s 408ms/step - loss: 3143.3213 - accuracy: 0.3172 - val_loss: 2017.2068 - val_accuracy: 0.3485
# Epoch 3/50
# 58/58 [==============================] - 26s 381ms/step - loss: 2787.2285 - accuracy: 0.3313 - val_loss: 3069.2202 - val_accuracy: 0.2413
# Epoch 4/50
# 58/58 [==============================] - 24s 341ms/step - loss: 2277.4155 - accuracy: 0.3558 - val_loss: 2094.4185 - val_accuracy: 0.2922
# Epoch 5/50
# 58/58 [==============================] - 24s 368ms/step - loss: 1828.6846 - accuracy: 0.3634 - val_loss: 4890.4629 - val_accuracy: 0.2359
# Epoch 6/50
# 58/58 [==============================] - 27s 405ms/step - loss: 2275.4885 - accuracy: 0.3542 - val_loss: 1802.8212 - val_accuracy: 0.3405
# Epoch 7/50
# 58/58 [==============================] - 27s 406ms/step - loss: 1760.4315 - accuracy: 0.3580 - val_loss: 1098.0204 - val_accuracy: 0.3485
# Epoch 8/50
# 58/58 [==============================] - 28s 414ms/step - loss: 563.5222 - accuracy: 0.4291 - val_loss: 934.6018 - val_accuracy: 0.3592
# Epoch 9/50
# 58/58 [==============================] - 27s 397ms/step - loss: 376.9045 - accuracy: 0.4356 - val_loss: 441.4211 - val_accuracy: 0.3405
# Epoch 10/50
# 58/58 [==============================] - 24s 367ms/step - loss: 349.2459 - accuracy: 0.4508 - val_loss: 504.1518 - val_accuracy: 0.3137
# Epoch 11/50
# 58/58 [==============================] - 25s 376ms/step - loss: 520.7391 - accuracy: 0.3965 - val_loss: 553.0148 - val_accuracy: 0.3512
# Epoch 12/50
# 58/58 [==============================] - 26s 388ms/step - loss: 414.9598 - accuracy: 0.4139 - val_loss: 590.8728 - val_accuracy: 0.3539
# Epoch 13/50
# 58/58 [==============================] - 28s 433ms/step - loss: 240.4526 - accuracy: 0.4601 - val_loss: 307.3083 - val_accuracy: 0.3405
# Epoch 14/50
# 58/58 [==============================] - 28s 401ms/step - loss: 210.0747 - accuracy: 0.4470 - val_loss: 289.4617 - val_accuracy: 0.2922
# Epoch 15/50
# 58/58 [==============================] - 25s 363ms/step - loss: 340.4897 - accuracy: 0.4079 - val_loss: 457.4338 - val_accuracy: 0.3271
# Epoch 16/50
# 58/58 [==============================] - 27s 396ms/step - loss: 207.3232 - accuracy: 0.4221 - val_loss: 183.2023 - val_accuracy: 0.3566
# Epoch 17/50
# 58/58 [==============================] - 24s 345ms/step - loss: 94.1307 - accuracy: 0.5263 - val_loss: 187.3681 - val_accuracy: 0.3432
# Epoch 18/50
# 58/58 [==============================] - 27s 418ms/step - loss: 102.4746 - accuracy: 0.5057 - val_loss: 120.8967 - val_accuracy: 0.4075
# Epoch 19/50
# 58/58 [==============================] - 26s 390ms/step - loss: 92.8296 - accuracy: 0.5100 - val_loss: 201.9714 - val_accuracy: 0.3298
# Epoch 20/50
# 58/58 [==============================] - 25s 367ms/step - loss: 72.2599 - accuracy: 0.5535 - val_loss: 126.3104 - val_accuracy: 0.3324
# Epoch 21/50
# 58/58 [==============================] - 31s 484ms/step - loss: 64.9173 - accuracy: 0.5617 - val_loss: 91.9906 - val_accuracy: 0.4209
# Epoch 22/50
# 58/58 [==============================] - 25s 354ms/step - loss: 61.3399 - accuracy: 0.5540 - val_loss: 93.3756 - val_accuracy: 0.2922
# Epoch 23/50
# 58/58 [==============================] - 25s 354ms/step - loss: 49.4314 - accuracy: 0.5513 - val_loss: 104.2238 - val_accuracy: 0.3244
# Epoch 24/50
# 58/58 [==============================] - 24s 369ms/step - loss: 119.5310 - accuracy: 0.4514 - val_loss: 371.9736 - val_accuracy: 0.1903
# Epoch 25/50
# 58/58 [==============================] - 26s 390ms/step - loss: 113.7938 - accuracy: 0.4394 - val_loss: 126.1846 - val_accuracy: 0.3780
# Epoch 26/50
# 58/58 [==============================] - 28s 422ms/step - loss: 56.6826 - accuracy: 0.4965 - val_loss: 67.6253 - val_accuracy: 0.3753
# Epoch 27/50
# 58/58 [==============================] - 28s 422ms/step - loss: 23.9767 - accuracy: 0.5763 - val_loss: 61.4511 - val_accuracy: 0.3592
# Epoch 28/50
# 58/58 [==============================] - 28s 426ms/step - loss: 25.9078 - accuracy: 0.5665 - val_loss: 40.2026 - val_accuracy: 0.4182
# Epoch 29/50
# 58/58 [==============================] - 26s 367ms/step - loss: 17.8312 - accuracy: 0.6225 - val_loss: 43.7992 - val_accuracy: 0.4155
# Epoch 30/50
# 58/58 [==============================] - 28s 420ms/step - loss: 29.9534 - accuracy: 0.5464 - val_loss: 38.6077 - val_accuracy: 0.3700
# Epoch 31/50
# 58/58 [==============================] - 25s 364ms/step - loss: 22.8617 - accuracy: 0.5356 - val_loss: 41.7248 - val_accuracy: 0.3807
# Epoch 32/50
# 58/58 [==============================] - 25s 374ms/step - loss: 13.4262 - accuracy: 0.6274 - val_loss: 39.7115 - val_accuracy: 0.3887
# Epoch 33/50
# 58/58 [==============================] - 28s 431ms/step - loss: 19.0807 - accuracy: 0.5649 - val_loss: 33.1190 - val_accuracy: 0.3995
# Epoch 34/50
# 58/58 [==============================] - 25s 379ms/step - loss: 27.5929 - accuracy: 0.4981 - val_loss: 48.7001 - val_accuracy: 0.3512
# Epoch 35/50
# 58/58 [==============================] - 27s 408ms/step - loss: 12.4383 - accuracy: 0.5953 - val_loss: 29.5810 - val_accuracy: 0.4531
# Epoch 36/50
# 58/58 [==============================] - 27s 407ms/step - loss: 10.8502 - accuracy: 0.6203 - val_loss: 20.0025 - val_accuracy: 0.3941
# Epoch 37/50
# 58/58 [==============================] - 27s 384ms/step - loss: 4.9538 - accuracy: 0.6936 - val_loss: 16.5927 - val_accuracy: 0.4290
# Epoch 38/50
# 58/58 [==============================] - 24s 348ms/step - loss: 6.2485 - accuracy: 0.6855 - val_loss: 24.8644 - val_accuracy: 0.3432
# Epoch 39/50
# 58/58 [==============================] - 25s 362ms/step - loss: 7.8753 - accuracy: 0.6225 - val_loss: 20.0146 - val_accuracy: 0.3727
# Epoch 40/50
# 58/58 [==============================] - 24s 365ms/step - loss: 4.4760 - accuracy: 0.7116 - val_loss: 20.4464 - val_accuracy: 0.3619
# Epoch 41/50
# 58/58 [==============================] - 24s 339ms/step - loss: 8.8132 - accuracy: 0.5872 - val_loss: 21.8548 - val_accuracy: 0.3539
# Epoch 42/50
# 58/58 [==============================] - 28s 424ms/step - loss: 4.8929 - accuracy: 0.6638 - val_loss: 12.5059 - val_accuracy: 0.4048
# Epoch 43/50
# 58/58 [==============================] - 26s 375ms/step - loss: 3.4085 - accuracy: 0.7078 - val_loss: 20.0459 - val_accuracy: 0.3914
# Epoch 44/50
# 58/58 [==============================] - 28s 428ms/step - loss: 3.3835 - accuracy: 0.6871 - val_loss: 9.3108 - val_accuracy: 0.4424
# Epoch 45/50
# 58/58 [==============================] - 26s 391ms/step - loss: 4.2588 - accuracy: 0.6393 - val_loss: 16.9213 - val_accuracy: 0.3432
# Epoch 46/50
# 58/58 [==============================] - 28s 437ms/step - loss: 2.9681 - accuracy: 0.6839 - val_loss: 9.2762 - val_accuracy: 0.4290
# Epoch 47/50
# 58/58 [==============================] - 26s 379ms/step - loss: 10.9733 - accuracy: 0.5030 - val_loss: 21.7846 - val_accuracy: 0.3298
# Epoch 48/50
# 58/58 [==============================] - 27s 402ms/step - loss: 8.6826 - accuracy: 0.5274 - val_loss: 13.2497 - val_accuracy: 0.3619
# Epoch 49/50
# 58/58 [==============================] - 28s 436ms/step - loss: 2.7930 - accuracy: 0.6784 - val_loss: 7.2557 - val_accuracy: 0.4665
# Epoch 50/50
# 58/58 [==============================] - 25s 383ms/step - loss: 2.5058 - accuracy: 0.7078 - val_loss: 7.6359 - val_accuracy: 0.4236

# %%
train_loss, val_loss = H.history['loss'], H.history['val_loss']
train_acc, val_acc = H.history['accuracy'], H.history['val_accuracy']
fig, axs = plt.subplots(figsize=(8,3), nrows=1, ncols=2)
num_epochs = np.arange(len(train_loss))
axs[0].plot(num_epochs, train_loss)
axs[0].plot(num_epochs, val_loss)
axs[0].set_ylabel('loss')
axs[0].set_xlabel('epoch')
axs[0].set_title('model loss')
axs[0].legend(['train', 'validation'], loc='upper right')
axs[1].plot(num_epochs, train_acc)
axs[1].plot(num_epochs, val_acc)
axs[1].set_ylabel('acc')
axs[1].set_xlabel('epoch')
axs[1].set_title('model accuracy')
axs[1].legend(['train', 'validation'], loc='upper right')
plt.tight_layout()
plt.show()

# %%
test_model = load_model("mlp.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 16/16 [==============================] - 2s 52ms/step - loss: 8.1099 - accuracy: 0.4536
# Test accuracy: 0.454

# %% [markdown]
# **Mô hình CNN**

# %%
def CNN():
 inputs = Input(shape=(224,224,3))
 x = Rescaling(1.0/255)(inputs)
 x = Conv2D(filters=32,kernel_size=(3,3), activation='relu')(x)
 x = MaxPooling2D(pool_size=(2,2))(x)

 x = Conv2D(filters=64,kernel_size=(3,3), activation='relu')(x)
 x = MaxPooling2D(pool_size=(2,2))(x)

 x = Conv2D(filters=128,kernel_size=(3,3), activation='relu')(x)
 x = MaxPooling2D(pool_size=(2,2))(x)

 x = Conv2D(filters=256,kernel_size=(3,3), activation='relu')(x)
 x = MaxPooling2D(pool_size=(2,2))(x)

 x = Conv2D(filters=512,kernel_size=(3,3), activation='relu')(x)
 x = MaxPooling2D(pool_size=(2,2))(x)

 x = Flatten()(x)

 outputs = Dense(units=5, activation='softmax')(x)
 model = Model(inputs = inputs, outputs=outputs)
 return model
# Tạo model
model = CNN()
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 256)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 512)       1180160
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 5)                 64005
#
# =================================================================
# Total params: 1632581 (6.23 MB)
# Trainable params: 1632581 (6.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Compile mô hình
model.compile(loss="categorical_crossentropy",
 optimizer="adam",
 metrics=["accuracy"])
callbacks = [ ModelCheckpoint(
 filepath="cnn.keras",
 save_best_only=True,
 monitor="val_loss")
]
# train mô hình
H = model.fit(
 train_dataset,
 epochs=50,
 validation_data=validation_dataset,
 callbacks=callbacks)
# Out:
# Epoch 1/50
# 58/58 [==============================] - 510s 8s/step - loss: 1.5520 - accuracy: 0.2944 - val_loss: 1.4615 - val_accuracy: 0.3753
# Epoch 2/50
# 58/58 [==============================] - 24s 368ms/step - loss: 1.3511 - accuracy: 0.4454 - val_loss: 1.4250 - val_accuracy: 0.4048
# Epoch 3/50
# 58/58 [==============================] - 24s 358ms/step - loss: 1.1368 - accuracy: 0.5464 - val_loss: 1.2182 - val_accuracy: 0.4933
# Epoch 4/50
# 58/58 [==============================] - 25s 374ms/step - loss: 1.0073 - accuracy: 0.5921 - val_loss: 1.1690 - val_accuracy: 0.5308
# Epoch 5/50
# 58/58 [==============================] - 25s 374ms/step - loss: 0.9132 - accuracy: 0.6317 - val_loss: 1.1437 - val_accuracy: 0.5201
# Epoch 6/50
# 58/58 [==============================] - 23s 353ms/step - loss: 0.8137 - accuracy: 0.6936 - val_loss: 1.0728 - val_accuracy: 0.5684
# Epoch 7/50
# 58/58 [==============================] - 24s 353ms/step - loss: 0.6476 - accuracy: 0.7550 - val_loss: 1.1058 - val_accuracy: 0.5898
# Epoch 8/50
# 58/58 [==============================] - 24s 368ms/step - loss: 0.5321 - accuracy: 0.8012 - val_loss: 1.1115 - val_accuracy: 0.6005
# Epoch 9/50
# 58/58 [==============================] - 25s 379ms/step - loss: 0.4293 - accuracy: 0.8392 - val_loss: 1.3098 - val_accuracy: 0.6220
# Epoch 10/50
# 58/58 [==============================] - 25s 371ms/step - loss: 0.3254 - accuracy: 0.8805 - val_loss: 1.4543 - val_accuracy: 0.6005
# Epoch 11/50
# 58/58 [==============================] - 24s 357ms/step - loss: 0.2583 - accuracy: 0.9109 - val_loss: 1.4645 - val_accuracy: 0.6247
# Epoch 12/50
# 58/58 [==============================] - 25s 358ms/step - loss: 0.2590 - accuracy: 0.9011 - val_loss: 1.5769 - val_accuracy: 0.6300
# Epoch 13/50
# 58/58 [==============================] - 25s 365ms/step - loss: 0.1568 - accuracy: 0.9511 - val_loss: 1.6959 - val_accuracy: 0.6461
# Epoch 14/50
# 58/58 [==============================] - 25s 377ms/step - loss: 0.1542 - accuracy: 0.9473 - val_loss: 1.8010 - val_accuracy: 0.6247
# Epoch 15/50
# 58/58 [==============================] - 25s 377ms/step - loss: 0.1887 - accuracy: 0.9364 - val_loss: 1.7283 - val_accuracy: 0.6381
# Epoch 16/50
# 58/58 [==============================] - 25s 361ms/step - loss: 0.1150 - accuracy: 0.9625 - val_loss: 1.9077 - val_accuracy: 0.6542
# Epoch 17/50
# 58/58 [==============================] - 25s 369ms/step - loss: 0.0771 - accuracy: 0.9761 - val_loss: 2.2436 - val_accuracy: 0.6488
# Epoch 18/50
# 58/58 [==============================] - 25s 355ms/step - loss: 0.0898 - accuracy: 0.9804 - val_loss: 2.2460 - val_accuracy: 0.6300
# Epoch 19/50
# 58/58 [==============================] - 25s 381ms/step - loss: 0.1010 - accuracy: 0.9712 - val_loss: 2.2744 - val_accuracy: 0.6327
# Epoch 20/50
# 58/58 [==============================] - 25s 376ms/step - loss: 0.1196 - accuracy: 0.9576 - val_loss: 2.4342 - val_accuracy: 0.6086
# Epoch 21/50
# 58/58 [==============================] - 25s 374ms/step - loss: 0.1189 - accuracy: 0.9620 - val_loss: 1.8586 - val_accuracy: 0.6568
# Epoch 22/50
# 58/58 [==============================] - 25s 375ms/step - loss: 0.0442 - accuracy: 0.9859 - val_loss: 2.3756 - val_accuracy: 0.6729
# Epoch 23/50
# 58/58 [==============================] - 24s 361ms/step - loss: 0.0436 - accuracy: 0.9859 - val_loss: 2.5440 - val_accuracy: 0.6434
# Epoch 24/50
# 58/58 [==============================] - 24s 354ms/step - loss: 0.0355 - accuracy: 0.9913 - val_loss: 2.9163 - val_accuracy: 0.6488
# Epoch 25/50
# 58/58 [==============================] - 25s 381ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 3.1066 - val_accuracy: 0.6649
# Epoch 26/50
# 58/58 [==============================] - 24s 367ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 3.0267 - val_accuracy: 0.6595
# Epoch 27/50
# 58/58 [==============================] - 25s 372ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 3.2297 - val_accuracy: 0.6649
# Epoch 28/50
# 58/58 [==============================] - 25s 376ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 3.2903 - val_accuracy: 0.6622
# Epoch 29/50
# 58/58 [==============================] - 25s 370ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 3.3523 - val_accuracy: 0.6595
# Epoch 30/50
# 58/58 [==============================] - 24s 356ms/step - loss: 7.2132e-04 - accuracy: 1.0000 - val_loss: 3.5174 - val_accuracy: 0.6622
# Epoch 31/50
# 58/58 [==============================] - 25s 354ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.5457 - val_accuracy: 0.6568
# Epoch 32/50
# 58/58 [==============================] - 25s 368ms/step - loss: 5.3496e-04 - accuracy: 1.0000 - val_loss: 3.5852 - val_accuracy: 0.6542
# Epoch 33/50
# 58/58 [==============================] - 25s 381ms/step - loss: 4.0964e-04 - accuracy: 1.0000 - val_loss: 3.6190 - val_accuracy: 0.6595
# Epoch 34/50
# 58/58 [==============================] - 25s 371ms/step - loss: 2.4210e-04 - accuracy: 1.0000 - val_loss: 3.6483 - val_accuracy: 0.6595
# Epoch 35/50
# 58/58 [==============================] - 25s 375ms/step - loss: 1.8571e-04 - accuracy: 1.0000 - val_loss: 3.6910 - val_accuracy: 0.6649
# Epoch 36/50
# 58/58 [==============================] - 25s 378ms/step - loss: 1.5936e-04 - accuracy: 1.0000 - val_loss: 3.7200 - val_accuracy: 0.6729
# Epoch 37/50
# 58/58 [==============================] - 25s 355ms/step - loss: 1.4784e-04 - accuracy: 1.0000 - val_loss: 3.7511 - val_accuracy: 0.6729
# Epoch 38/50
# 58/58 [==============================] - 25s 355ms/step - loss: 1.2422e-04 - accuracy: 1.0000 - val_loss: 3.7848 - val_accuracy: 0.6649
# Epoch 39/50
# 58/58 [==============================] - 25s 365ms/step - loss: 1.0491e-04 - accuracy: 1.0000 - val_loss: 3.8081 - val_accuracy: 0.6729
# Epoch 40/50
# 58/58 [==============================] - 25s 375ms/step - loss: 9.4241e-05 - accuracy: 1.0000 - val_loss: 3.8352 - val_accuracy: 0.6649
# Epoch 41/50
# 58/58 [==============================] - 25s 382ms/step - loss: 8.5474e-05 - accuracy: 1.0000 - val_loss: 3.8600 - val_accuracy: 0.6702
# Epoch 42/50
# 58/58 [==============================] - 25s 382ms/step - loss: 7.7659e-05 - accuracy: 1.0000 - val_loss: 3.8820 - val_accuracy: 0.6702
# Epoch 43/50
# 58/58 [==============================] - 25s 378ms/step - loss: 7.4197e-05 - accuracy: 1.0000 - val_loss: 3.9057 - val_accuracy: 0.6702
# Epoch 44/50
# 58/58 [==============================] - 25s 380ms/step - loss: 6.8392e-05 - accuracy: 1.0000 - val_loss: 3.9300 - val_accuracy: 0.6676
# Epoch 45/50
# 58/58 [==============================] - 25s 379ms/step - loss: 6.0093e-05 - accuracy: 1.0000 - val_loss: 3.9486 - val_accuracy: 0.6702
# Epoch 46/50
# 58/58 [==============================] - 26s 395ms/step - loss: 5.6398e-05 - accuracy: 1.0000 - val_loss: 3.9704 - val_accuracy: 0.6702
# Epoch 47/50
# 58/58 [==============================] - 25s 386ms/step - loss: 5.0756e-05 - accuracy: 1.0000 - val_loss: 3.9899 - val_accuracy: 0.6702
# Epoch 48/50
# 58/58 [==============================] - 26s 387ms/step - loss: 4.7692e-05 - accuracy: 1.0000 - val_loss: 4.0082 - val_accuracy: 0.6702
# Epoch 49/50
# 58/58 [==============================] - 25s 353ms/step - loss: 4.4522e-05 - accuracy: 1.0000 - val_loss: 4.0270 - val_accuracy: 0.6702
# Epoch 50/50
# 58/58 [==============================] - 24s 370ms/step - loss: 4.1020e-05 - accuracy: 1.0000 - val_loss: 4.0445 - val_accuracy: 0.6702

# %%
train_loss, val_loss = H.history['loss'], H.history['val_loss']
train_acc, val_acc = H.history['accuracy'], H.history['val_accuracy']
fig, axs = plt.subplots(figsize=(8,3), nrows=1, ncols=2)
num_epochs = np.arange(len(train_loss))
axs[0].plot(num_epochs, train_loss)
axs[0].plot(num_epochs, val_loss)
axs[0].set_ylabel('loss')
axs[0].set_xlabel('epoch')
axs[0].set_title('model loss')
axs[0].legend(['train', 'validation'], loc='upper right')
axs[1].plot(num_epochs, train_acc)
axs[1].plot(num_epochs, val_acc)
axs[1].set_ylabel('acc')
axs[1].set_xlabel('epoch')
axs[1].set_title('model accuracy')
axs[1].legend(['train', 'validation'], loc='upper right')
plt.tight_layout()
plt.show()

# %%
test_model = load_model("cnn.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 16/16 [==============================] - 122s 3s/step - loss: 1.1024 - accuracy: 0.6008
# Test accuracy: 0.601

# %% [markdown]
# **Mô hình ResNet**

# %%
def identity_block(X, filters):
  F1, F2, F3 = filters

  shortcut = X
  # 1 Convolution 1x1
  X = Conv2D(filters=F1, kernel_size=(1,1), strides=(1,1), padding='valid')(X)
  X = BatchNormalization(axis = 3)(X)
  X = Activation('relu')(X)
  # 2 Convolution 3x3
  X = Conv2D(filters=F2, kernel_size=(3,3), strides=(1,1), padding='same')(X)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  # 3 Convolution 1x1
  X = Conv2D(filters=F3, kernel_size=(1,1), strides=(1,1), padding='valid')(X)
  X = BatchNormalization(axis = 3)(X)
  # 4 shortcut
  X = Add()([shortcut,X])
  X = Activation('relu')(X)
  return X

# %%
input_shape = (32,32,16)
input = Input(shape = input_shape)
output = identity_block(input, filters=[16,16,16])
model = Model(inputs=input, outputs=output)
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 16)]         0         []
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 16)           272       ['input_2[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 16)           64        ['conv2d_5[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 16)           0         ['batch_normalization[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 16)           2320      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 16)           64        ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 16)           272       ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 16)           64        ['conv2d_7[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 32, 32, 16)           0         ['input_2[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_2 (Activation)   (None, 32, 32, 16)           0         ['add[0][0]']
#
# ==================================================================================================
# Total params: 3056 (11.94 KB)
# Trainable params: 2960 (11.56 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
def convolutional_block(X, filters, s=2):
 F1, F2, F3 = filters

 # Lưu giá trị Input (tạo shortcut)
 shortcut = X
 # 1. Convolution 1x1
 X = Conv2D(filters=F1, kernel_size=(1,1), strides=(s,s), padding='valid')(X)
 X = BatchNormalization(axis=3)(X)
 X = Activation('relu')(X)
 # 2. Convolution 3x3
 X = Conv2D(filters=F2, kernel_size=(3,3),strides=(1,1), padding='same')(X)
 X = BatchNormalization(axis=3)(X)
 X = Activation('relu')(X)
 # 3. Convolution 1x1
 X = Conv2D(filters=F3, kernel_size=(1,1), strides=(1,1), padding='valid')(X)
 X = BatchNormalization(axis=3)(X)
 # 4. Convolutional shortcut
 shortcut = Conv2D(filters=F3, kernel_size=(1,1), strides=(s,s), padding='valid')(shortcut)
 shortcut = BatchNormalization(axis=3)(shortcut)
 # 5. Shortcut
 X = Add()([X, shortcut])
 X = Activation('relu')(X)
 return X

# %%
input = Input(shape=(32,32,16))
output = convolutional_block(input, filters=[16,16,16])
model = Model(inputs=input, outputs=output)
print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 16)]         0         []
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 16)           272       ['input_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 16, 16)           64        ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 16)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 16)           2320      ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 16, 16, 16)           64        ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 16, 16, 16)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 16)           272       ['activation_4[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 16)           272       ['input_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 16, 16, 16)           64        ['conv2d_10[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 16, 16, 16)           64        ['conv2d_11[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 16, 16, 16)           0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ']
#
#  activation_5 (Activation)   (None, 16, 16, 16)           0         ['add_1[0][0]']
#
# ==================================================================================================
# Total params: 3392 (13.25 KB)
# Trainable params: 3264 (12.75 KB)
# Non-trainable params: 128 (512.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
def ResNet50(input_shape=(224, 224, 3), classes=5):
 input = Input(input_shape)
 # Zero-Padding
 X = ZeroPadding2D((3, 3))(input)
 # Stage 1
 X = Conv2D(64, (7,7), strides=(2,2))(X)
 X = BatchNormalization(axis=3)(X)
 X = Activation('relu')(X)
 X = MaxPooling2D((3,3), strides=(2,2))(X)
 # Stage 2
 X = convolutional_block(X, filters=[64,64,256], s=1)
 X = identity_block(X, filters=[64,64,256])
 X = identity_block(X, filters=[64,64,256])
 # Stage 3
 X = convolutional_block(X, filters=[128,128,512], s=2)
 X = identity_block(X, filters=[128,128,512])
 X = identity_block(X, filters=[128,128,512])
 X = identity_block(X, filters=[128,128,512])
 # Stage 4
 X = convolutional_block(X, filters=[256,256,1024], s=2)
 X = identity_block(X, filters=[256, 256, 1024])
 X = identity_block(X, filters=[256, 256, 1024])
 X = identity_block(X, filters=[256, 256, 1024])
 X = identity_block(X, filters=[256, 256, 1024])
 X = identity_block(X, filters=[256, 256, 1024])
 # Stage 5
 X = convolutional_block(X, filters=[512,512,2048], s=2)
 X = identity_block(X, filters=[512,512,2048])
 X = identity_block(X, filters=[512,512,2048])
 X = GlobalAveragePooling2D()(X)
 # output layer
 X = Flatten()(X)
 X = Dense(classes, activation='softmax')(X)
 # Tạo model
 model = Model(inputs=input, outputs=X)
 return model
model = ResNet50()
print(model.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_4[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 112, 112, 64)         9472      ['zero_padding2d[0][0]']
#
#  batch_normalization_7 (Bat  (None, 112, 112, 64)         256       ['conv2d_12[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 112, 112, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_5 (MaxPoolin  (None, 55, 55, 64)           0         ['activation_6[0][0]']
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 55, 55, 64)           4160      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_8 (Bat  (None, 55, 55, 64)           256       ['conv2d_13[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 55, 55, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_14 (Conv2D)          (None, 55, 55, 64)           36928     ['activation_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 55, 55, 64)           256       ['conv2d_14[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 55, 55, 64)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_15 (Conv2D)          (None, 55, 55, 256)          16640     ['activation_8[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 55, 55, 256)          16640     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_10 (Ba  (None, 55, 55, 256)          1024      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 55, 55, 256)          1024      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  add_2 (Add)                 (None, 55, 55, 256)          0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_9 (Activation)   (None, 55, 55, 256)          0         ['add_2[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 55, 55, 64)           16448     ['activation_9[0][0]']
#
#  batch_normalization_12 (Ba  (None, 55, 55, 64)           256       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 55, 55, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 55, 55, 64)           36928     ['activation_10[0][0]']
#
#  batch_normalization_13 (Ba  (None, 55, 55, 64)           256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 55, 55, 64)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 55, 55, 256)          16640     ['activation_11[0][0]']
#
#  batch_normalization_14 (Ba  (None, 55, 55, 256)          1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 55, 55, 256)          0         ['activation_9[0][0]',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 55, 55, 256)          0         ['add_3[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 55, 55, 64)           16448     ['activation_12[0][0]']
#
#  batch_normalization_15 (Ba  (None, 55, 55, 64)           256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 55, 55, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 55, 55, 64)           36928     ['activation_13[0][0]']
#
#  batch_normalization_16 (Ba  (None, 55, 55, 64)           256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 55, 55, 64)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 55, 55, 256)          16640     ['activation_14[0][0]']
#
#  batch_normalization_17 (Ba  (None, 55, 55, 256)          1024      ['conv2d_22[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 55, 55, 256)          0         ['activation_12[0][0]',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 55, 55, 256)          0         ['add_4[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 28, 28, 128)          32896     ['activation_15[0][0]']
#
#  batch_normalization_18 (Ba  (None, 28, 28, 128)          512       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_16[0][0]']
#
#  batch_normalization_19 (Ba  (None, 28, 28, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 512)          66048     ['activation_17[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 512)          131584    ['activation_15[0][0]']
#
#  batch_normalization_20 (Ba  (None, 28, 28, 512)          2048      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 28, 28, 512)          2048      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 28, 28, 512)          0         ['batch_normalization_20[0][0]
#                                                                     ',
#                                                                      'batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 28, 28, 512)          0         ['add_5[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 128)          65664     ['activation_18[0][0]']
#
#  batch_normalization_22 (Ba  (None, 28, 28, 128)          512       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_19[0][0]']
#
#  batch_normalization_23 (Ba  (None, 28, 28, 128)          512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 28, 28, 512)          66048     ['activation_20[0][0]']
#
#  batch_normalization_24 (Ba  (None, 28, 28, 512)          2048      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 28, 28, 512)          0         ['activation_18[0][0]',
#                                                                      'batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 28, 28, 512)          0         ['add_6[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 28, 28, 128)          65664     ['activation_21[0][0]']
#
#  batch_normalization_25 (Ba  (None, 28, 28, 128)          512       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_22[0][0]']
#
#  batch_normalization_26 (Ba  (None, 28, 28, 128)          512       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 512)          66048     ['activation_23[0][0]']
#
#  batch_normalization_27 (Ba  (None, 28, 28, 512)          2048      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 28, 28, 512)          0         ['activation_21[0][0]',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 28, 28, 512)          0         ['add_7[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 128)          65664     ['activation_24[0][0]']
#
#  batch_normalization_28 (Ba  (None, 28, 28, 128)          512       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_25[0][0]']
#
#  batch_normalization_29 (Ba  (None, 28, 28, 128)          512       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 28, 28, 512)          66048     ['activation_26[0][0]']
#
#  batch_normalization_30 (Ba  (None, 28, 28, 512)          2048      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 28, 28, 512)          0         ['activation_24[0][0]',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 28, 28, 512)          0         ['add_8[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 14, 14, 256)          131328    ['activation_27[0][0]']
#
#  batch_normalization_31 (Ba  (None, 14, 14, 256)          1024      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_28[0][0]']
#
#  batch_normalization_32 (Ba  (None, 14, 14, 256)          1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 14, 14, 1024)         263168    ['activation_29[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 1024)         525312    ['activation_27[0][0]']
#
#  batch_normalization_33 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 14, 14, 1024)         0         ['batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'batch_normalization_34[0][0]
#                                                                     ']
#
#  activation_30 (Activation)  (None, 14, 14, 1024)         0         ['add_9[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 256)          262400    ['activation_30[0][0]']
#
#  batch_normalization_35 (Ba  (None, 14, 14, 256)          1024      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_31[0][0]']
#
#  batch_normalization_36 (Ba  (None, 14, 14, 256)          1024      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 1024)         263168    ['activation_32[0][0]']
#
#  batch_normalization_37 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 14, 14, 1024)         0         ['activation_30[0][0]',
#                                                                      'batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 14, 14, 1024)         0         ['add_10[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 256)          262400    ['activation_33[0][0]']
#
#  batch_normalization_38 (Ba  (None, 14, 14, 256)          1024      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_34[0][0]']
#
#  batch_normalization_39 (Ba  (None, 14, 14, 256)          1024      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 14, 14, 1024)         263168    ['activation_35[0][0]']
#
#  batch_normalization_40 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 14, 14, 1024)         0         ['activation_33[0][0]',
#                                                                      'batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 14, 14, 1024)         0         ['add_11[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 14, 14, 256)          262400    ['activation_36[0][0]']
#
#  batch_normalization_41 (Ba  (None, 14, 14, 256)          1024      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_37[0][0]']
#
#  batch_normalization_42 (Ba  (None, 14, 14, 256)          1024      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 14, 14, 1024)         263168    ['activation_38[0][0]']
#
#  batch_normalization_43 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 14, 14, 1024)         0         ['activation_36[0][0]',
#                                                                      'batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 14, 14, 1024)         0         ['add_12[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 14, 14, 256)          262400    ['activation_39[0][0]']
#
#  batch_normalization_44 (Ba  (None, 14, 14, 256)          1024      ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_40[0][0]']
#
#  batch_normalization_45 (Ba  (None, 14, 14, 256)          1024      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 14, 14, 1024)         263168    ['activation_41[0][0]']
#
#  batch_normalization_46 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_51[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 14, 14, 1024)         0         ['activation_39[0][0]',
#                                                                      'batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_42 (Activation)  (None, 14, 14, 1024)         0         ['add_13[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 14, 14, 256)          262400    ['activation_42[0][0]']
#
#  batch_normalization_47 (Ba  (None, 14, 14, 256)          1024      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_53 (Conv2D)          (None, 14, 14, 256)          590080    ['activation_43[0][0]']
#
#  batch_normalization_48 (Ba  (None, 14, 14, 256)          1024      ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 14, 14, 256)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 14, 14, 1024)         263168    ['activation_44[0][0]']
#
#  batch_normalization_49 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_54[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 14, 14, 1024)         0         ['activation_42[0][0]',
#                                                                      'batch_normalization_49[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 14, 14, 1024)         0         ['add_14[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 7, 7, 512)            524800    ['activation_45[0][0]']
#
#  batch_normalization_50 (Ba  (None, 7, 7, 512)            2048      ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 7, 7, 512)            0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_56 (Conv2D)          (None, 7, 7, 512)            2359808   ['activation_46[0][0]']
#
#  batch_normalization_51 (Ba  (None, 7, 7, 512)            2048      ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 7, 7, 512)            0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 7, 7, 2048)           1050624   ['activation_47[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 7, 7, 2048)           2099200   ['activation_45[0][0]']
#
#  batch_normalization_52 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_57[0][0]']
#  tchNormalization)
#
#  batch_normalization_53 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_58[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 7, 7, 2048)           0         ['batch_normalization_52[0][0]
#                                                                     ',
#                                                                      'batch_normalization_53[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 7, 7, 2048)           0         ['add_15[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 7, 7, 512)            1049088   ['activation_48[0][0]']
#
#  batch_normalization_54 (Ba  (None, 7, 7, 512)            2048      ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 7, 7, 512)            0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 7, 7, 512)            2359808   ['activation_49[0][0]']
#
#  batch_normalization_55 (Ba  (None, 7, 7, 512)            2048      ['conv2d_60[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 7, 7, 512)            0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_61 (Conv2D)          (None, 7, 7, 2048)           1050624   ['activation_50[0][0]']
#
#  batch_normalization_56 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_61[0][0]']
#  tchNormalization)
#
#  add_16 (Add)                (None, 7, 7, 2048)           0         ['activation_48[0][0]',
#                                                                      'batch_normalization_56[0][0]
#                                                                     ']
#
#  activation_51 (Activation)  (None, 7, 7, 2048)           0         ['add_16[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 7, 7, 512)            1049088   ['activation_51[0][0]']
#
#  batch_normalization_57 (Ba  (None, 7, 7, 512)            2048      ['conv2d_62[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 7, 7, 512)            0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  conv2d_63 (Conv2D)          (None, 7, 7, 512)            2359808   ['activation_52[0][0]']
#
#  batch_normalization_58 (Ba  (None, 7, 7, 512)            2048      ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 7, 7, 512)            0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  conv2d_64 (Conv2D)          (None, 7, 7, 2048)           1050624   ['activation_53[0][0]']
#
#  batch_normalization_59 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_64[0][0]']
#  tchNormalization)
#
#  add_17 (Add)                (None, 7, 7, 2048)           0         ['activation_51[0][0]',
#                                                                      'batch_normalization_59[0][0]
#                                                                     ']
#
#  activation_54 (Activation)  (None, 7, 7, 2048)           0         ['add_17[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['activation_54[0][0]']
#  GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 2048)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 5)                    10245     ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 23597957 (90.02 MB)
# Trainable params: 23544837 (89.82 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________
# None

# %%
# Compile mô hình
model.compile(loss="categorical_crossentropy",
 optimizer="adam",
 metrics=["accuracy"])
callbacks = [ ModelCheckpoint(
 filepath="resnet.keras",
 save_best_only=True,
 monitor="val_loss")
]
# train mô hình
H = model.fit(
 train_dataset,
 epochs=50,
 validation_data=validation_dataset,
 callbacks=callbacks)
# Out:
# Epoch 1/50
# 58/58 [==============================] - 77s 633ms/step - loss: 2.0234 - accuracy: 0.3851 - val_loss: 9.4220 - val_accuracy: 0.2279
# Epoch 2/50
# 58/58 [==============================] - 34s 514ms/step - loss: 1.5357 - accuracy: 0.4188 - val_loss: 2.1810 - val_accuracy: 0.3164
# Epoch 3/50
# 58/58 [==============================] - 35s 540ms/step - loss: 1.4763 - accuracy: 0.4237 - val_loss: 1.9626 - val_accuracy: 0.3110
# Epoch 4/50
# 58/58 [==============================] - 32s 494ms/step - loss: 1.3150 - accuracy: 0.4861 - val_loss: 2.0994 - val_accuracy: 0.3619
# Epoch 5/50
# 58/58 [==============================] - 32s 493ms/step - loss: 1.3531 - accuracy: 0.4541 - val_loss: 27.3336 - val_accuracy: 0.2708
# Epoch 6/50
# 58/58 [==============================] - 33s 498ms/step - loss: 1.3217 - accuracy: 0.4764 - val_loss: 3.3668 - val_accuracy: 0.3029
# Epoch 7/50
# 58/58 [==============================] - 32s 495ms/step - loss: 1.2593 - accuracy: 0.4976 - val_loss: 52.9983 - val_accuracy: 0.3003
# Epoch 8/50
# 58/58 [==============================] - 32s 494ms/step - loss: 1.1871 - accuracy: 0.5339 - val_loss: 2.7540 - val_accuracy: 0.3432
# Epoch 9/50
# 58/58 [==============================] - 32s 492ms/step - loss: 1.1011 - accuracy: 0.5524 - val_loss: 16.7785 - val_accuracy: 0.3405
# Epoch 10/50
# 58/58 [==============================] - 32s 488ms/step - loss: 1.0642 - accuracy: 0.5807 - val_loss: 8.0494 - val_accuracy: 0.2654
# Epoch 11/50
# 58/58 [==============================] - 32s 502ms/step - loss: 1.0179 - accuracy: 0.6029 - val_loss: 2.1944 - val_accuracy: 0.3753
# Epoch 12/50
# 58/58 [==============================] - 32s 494ms/step - loss: 1.0218 - accuracy: 0.5980 - val_loss: 2.8376 - val_accuracy: 0.3861
# Epoch 13/50
# 58/58 [==============================] - 32s 481ms/step - loss: 0.9767 - accuracy: 0.6290 - val_loss: 2.3770 - val_accuracy: 0.2359
# Epoch 14/50
# 58/58 [==============================] - 34s 529ms/step - loss: 0.9228 - accuracy: 0.6415 - val_loss: 1.5966 - val_accuracy: 0.4504
# Epoch 15/50
# 58/58 [==============================] - 32s 470ms/step - loss: 0.8468 - accuracy: 0.6725 - val_loss: 3.9123 - val_accuracy: 0.2976
# Epoch 16/50
# 58/58 [==============================] - 33s 514ms/step - loss: 0.8422 - accuracy: 0.6763 - val_loss: 1.3985 - val_accuracy: 0.5335
# Epoch 17/50
# 58/58 [==============================] - 35s 535ms/step - loss: 0.7822 - accuracy: 0.7105 - val_loss: 3.9163 - val_accuracy: 0.3003
# Epoch 18/50
# 58/58 [==============================] - 32s 490ms/step - loss: 0.7740 - accuracy: 0.7175 - val_loss: 2.1743 - val_accuracy: 0.2842
# Epoch 19/50
# 58/58 [==============================] - 32s 494ms/step - loss: 0.7488 - accuracy: 0.7235 - val_loss: 6.1371 - val_accuracy: 0.3324
# Epoch 20/50
# 58/58 [==============================] - 31s 484ms/step - loss: 0.6865 - accuracy: 0.7371 - val_loss: 1.5081 - val_accuracy: 0.5013
# Epoch 21/50
# 58/58 [==============================] - 32s 498ms/step - loss: 0.6692 - accuracy: 0.7490 - val_loss: 3.9313 - val_accuracy: 0.4450
# Epoch 22/50
# 58/58 [==============================] - 34s 512ms/step - loss: 0.5320 - accuracy: 0.7941 - val_loss: 1.1248 - val_accuracy: 0.6408
# Epoch 23/50
# 58/58 [==============================] - 33s 508ms/step - loss: 0.5330 - accuracy: 0.7979 - val_loss: 2.8595 - val_accuracy: 0.4290
# Epoch 24/50
# 58/58 [==============================] - 32s 487ms/step - loss: 0.4880 - accuracy: 0.8235 - val_loss: 4.8917 - val_accuracy: 0.3056
# Epoch 25/50
# 58/58 [==============================] - 32s 488ms/step - loss: 0.4090 - accuracy: 0.8463 - val_loss: 1.9442 - val_accuracy: 0.5282
# Epoch 26/50
# 58/58 [==============================] - 31s 487ms/step - loss: 0.4130 - accuracy: 0.8561 - val_loss: 5.4811 - val_accuracy: 0.3458
# Epoch 27/50
# 58/58 [==============================] - 32s 472ms/step - loss: 0.3352 - accuracy: 0.8772 - val_loss: 42.8459 - val_accuracy: 0.2118
# Epoch 28/50
# 58/58 [==============================] - 32s 491ms/step - loss: 0.2889 - accuracy: 0.8963 - val_loss: 5.8641 - val_accuracy: 0.3566
# Epoch 29/50
# 58/58 [==============================] - 31s 492ms/step - loss: 0.3363 - accuracy: 0.8810 - val_loss: 2.0236 - val_accuracy: 0.5362
# Epoch 30/50
# 58/58 [==============================] - 32s 474ms/step - loss: 0.3355 - accuracy: 0.8772 - val_loss: 1.6724 - val_accuracy: 0.5764
# Epoch 31/50
# 58/58 [==============================] - 32s 494ms/step - loss: 0.2387 - accuracy: 0.9158 - val_loss: 2.8594 - val_accuracy: 0.4477
# Epoch 32/50
# 58/58 [==============================] - 34s 532ms/step - loss: 0.2344 - accuracy: 0.9202 - val_loss: 2.4251 - val_accuracy: 0.4933
# Epoch 33/50
# 58/58 [==============================] - 31s 486ms/step - loss: 0.2100 - accuracy: 0.9310 - val_loss: 5.3517 - val_accuracy: 0.3673
# Epoch 34/50
# 58/58 [==============================] - 32s 495ms/step - loss: 0.1479 - accuracy: 0.9571 - val_loss: 3.7212 - val_accuracy: 0.4826
# Epoch 35/50
# 58/58 [==============================] - 32s 479ms/step - loss: 0.1212 - accuracy: 0.9582 - val_loss: 1.8418 - val_accuracy: 0.5871
# Epoch 36/50
# 58/58 [==============================] - 32s 499ms/step - loss: 0.1552 - accuracy: 0.9495 - val_loss: 1.9887 - val_accuracy: 0.5845
# Epoch 37/50
# 58/58 [==============================] - 32s 497ms/step - loss: 0.1141 - accuracy: 0.9636 - val_loss: 2.0557 - val_accuracy: 0.5469
# Epoch 38/50
# 58/58 [==============================] - 34s 518ms/step - loss: 0.1348 - accuracy: 0.9517 - val_loss: 3.0305 - val_accuracy: 0.5255
# Epoch 39/50
# 58/58 [==============================] - 32s 489ms/step - loss: 0.1500 - accuracy: 0.9473 - val_loss: 2.4129 - val_accuracy: 0.5228
# Epoch 40/50
# 58/58 [==============================] - 32s 479ms/step - loss: 0.0586 - accuracy: 0.9821 - val_loss: 1.8874 - val_accuracy: 0.6086
# Epoch 41/50
# 58/58 [==============================] - 32s 493ms/step - loss: 0.0454 - accuracy: 0.9864 - val_loss: 1.9250 - val_accuracy: 0.6005
# Epoch 42/50
# 58/58 [==============================] - 33s 483ms/step - loss: 0.1835 - accuracy: 0.9354 - val_loss: 6.1009 - val_accuracy: 0.4692
# Epoch 43/50
# 58/58 [==============================] - 32s 493ms/step - loss: 0.1452 - accuracy: 0.9571 - val_loss: 6.4221 - val_accuracy: 0.5389
# Epoch 44/50
# 58/58 [==============================] - 33s 497ms/step - loss: 0.0988 - accuracy: 0.9669 - val_loss: 2.7464 - val_accuracy: 0.5630
# Epoch 45/50
# 58/58 [==============================] - 32s 493ms/step - loss: 0.1472 - accuracy: 0.9517 - val_loss: 2.0450 - val_accuracy: 0.6113
# Epoch 46/50
# 58/58 [==============================] - 34s 537ms/step - loss: 0.0912 - accuracy: 0.9745 - val_loss: 4.1164 - val_accuracy: 0.3780
# Epoch 47/50
# 58/58 [==============================] - 32s 492ms/step - loss: 0.0700 - accuracy: 0.9723 - val_loss: 2.6052 - val_accuracy: 0.5335
# Epoch 48/50
# 58/58 [==============================] - 32s 492ms/step - loss: 0.0862 - accuracy: 0.9739 - val_loss: 1.9161 - val_accuracy: 0.5979
# Epoch 49/50
# 58/58 [==============================] - 32s 476ms/step - loss: 0.0847 - accuracy: 0.9728 - val_loss: 2.9489 - val_accuracy: 0.4718
# Epoch 50/50
# 58/58 [==============================] - 32s 493ms/step - loss: 0.0762 - accuracy: 0.9734 - val_loss: 2.0994 - val_accuracy: 0.6300

# %%
train_loss, val_loss = H.history['loss'], H.history['val_loss']
train_acc, val_acc = H.history['accuracy'], H.history['val_accuracy']
fig, axs = plt.subplots(figsize=(8,3), nrows=1, ncols=2)
num_epochs = np.arange(len(train_loss))
axs[0].plot(num_epochs, train_loss)
axs[0].plot(num_epochs, val_loss)
axs[0].set_ylabel('loss')
axs[0].set_xlabel('epoch')
axs[0].set_title('model loss')
axs[0].legend(['train', 'validation'], loc='upper right')
axs[1].plot(num_epochs, train_acc)
axs[1].plot(num_epochs, val_acc)
axs[1].set_ylabel('acc')
axs[1].set_xlabel('epoch')
axs[1].set_title('model accuracy')
axs[1].legend(['train', 'validation'], loc='upper right')
plt.tight_layout()
plt.show()

# %%
test_model = load_model("resnet.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 16/16 [==============================] - 6s 198ms/step - loss: 1.1695 - accuracy: 0.6048
# Test accuracy: 0.605
